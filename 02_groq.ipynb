# %%
from dotenv import load_dotenv, find_dotenv
import os
from openai import OpenAI

load_dotenv(find_dotenv())

# Set your Groq API key as environment var, or replace directly
API_KEY = os.getenv("GROQ_API_KEY")

client = OpenAI(
    api_key=API_KEY,
    base_url="https://api.groq.com/openai/v1",
)

response = client.chat.completions.create(
    model="openai/gpt-oss-120b",
    messages=[
        { "role": "system", "content": "You are a helpful assistant." },
        { "role": "user",   "content": "Hello, who are you?" }
    ],
    temperature=0.7,
    reasoning_effort="medium",
    max_completion_tokens=8192,
    top_p=1
)

print(response.choices[0].message.content)
# Out:
# Hello! I’m ChatGPT, an AI language model created by OpenAI. I’m here to help answer your questions, discuss topics, brainstorm ideas, or just chat—whatever you need. How can I assist you today?
